# %% [markdown]
# # More examples
#
# More worked examples will be added here over time. Planned topics include:
#
# - **λ vs. orbital period / a-R\*** for hot Jupiters (separating aligned vs. misaligned populations).
# - **Mass–radius diagram** colour-coded by stellar obliquity.
# - **Hot vs. cool host stars** — Kraft-break separation of the obliquity distribution.
# - **WWB-only sub-sample** — our own RM measurements highlighted against the literature.
# - **True obliquity (ψ)** when stellar inclination is available.
